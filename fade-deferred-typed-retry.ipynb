# %% [markdown]
# # FADE — Deferred typed retry (the METHOD)
#
# Diagnose each failure; retry with TYPED exemplars matched to the cause + a hint-free typed instruction. Deferred: MEDIUM queue drains before BAD. Writes `store_typed/`.
#
# **Sidebar:** GPU on · Internet on · Secret `HF_TOKEN` (this account's, Llama-2 approved) (the shared eval order is committed in the repo — nothing to attach).
#
# The shared eval order is restored from that dataset so THIS arm evaluates the identical 1,319 problems as every other arm, on any account.

# %%
# 1. Deps + clone
import os, shutil
# !pip -q install -U "transformers>=4.40" accelerate sentence-transformers sympy scikit-learn datasets scipy 2>/dev/null | tail -1
REPO='/kaggle/working/fade'
if os.path.exists(REPO): shutil.rmtree(REPO)
# !git clone --depth 1 https://github.com/S2V3/fade.git {REPO}
print('cloned')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 32.2 MB/s eta 0:00:00
# Cloning into '/kaggle/working/fade'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 20 (delta 0), reused 10 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 352.42 KiB | 3.49 MiB/s, done.
# cloned

# %%
# 2. The shared eval order is COMMITTED IN THE REPO (artifacts/), so it arrives with the clone.
import os
adir=f'{REPO}/artifacts'
files=os.listdir(adir) if os.path.exists(adir) else []
ok=any('evalorder' in f for f in files)
assert ok, ('artifacts/ not in the repo. Prime it once locally (--build-artifacts-only) and '
            'commit artifacts/ to the repo, then re-clone. Got: '+str(files))
print('shared eval order present:', files)
# Out:
# shared eval order present: ['seeds_evalorder_pool2000_test.json']

# %%
# 3. Confirm HF token
from kaggle_secrets import UserSecretsClient
print('HF_TOKEN length', len(UserSecretsClient().get_secret('HF_TOKEN')))
# Out:
# HF_TOKEN length 37

# %%
# 4. Config — MUST be identical across ALL arms/accounts
MODEL='meta-llama/Llama-2-7b-chat-hf'; N=1319; BUDGET=8; TOK=320
print(MODEL, N, BUDGET, TOK)
# Out:
# meta-llama/Llama-2-7b-chat-hf 1319 8 320

# %%
# 5. RUN this arm (typed). Resumable: re-run to continue after a disconnect.
# !cd {REPO} && python kaggle_run.py --n-problems {N} --strategy 2 --split test \
    --model {MODEL} --retrieval 3stage --retry-mode typed --run-name typed \
    --exemplar-budget {BUDGET} --max-new-tokens {TOK} --show-every 50 --secret-name HF_TOKEN
# Out:
# Torch OK
#  sentence-transformers OK
# ======================================================================
#   generation module version: v5-hashline
#   v5-hashline ACTIVE | N_SHOTS=8 rep_penalty=1.15 no_repeat_ngram=6
#   ban_strings=['\\begin{code}', '\\end{code}', '```'] | stop_markers=['\nQuestion:', '\nQ:', '\nExample', '\nProblem:']
#   preprocessing: normalize_traces=True
# ======================================================================
#   exemplar budget: 8 (enforced across all arms)
#   model: meta-llama/Llama-2-7b-chat-hf
#   HF token loaded from Kaggle Secret 'HF_TOKEN'
#   HF identity: S2V3 (type=user)
#   gated-access probe OK: meta-llama/Llama-2-7b-chat-hf reachable (16 files)
#
# Loading GSM8K (train for seeds, test for eval)...
# README.md: 7.93kB [00:00, 4.01MB/s]
# main/train-00000-of-00001.parquet: 100%|███| 2.31M/2.31M [00:00<00:00, 2.76MB/s]
# main/test-00000-of-00001.parquet: 100%|██████| 419k/419k [00:00<00:00, 1.97MB/s]
# Generating train split: 100%|████| 7473/7473 [00:00<00:00, 142633.67 examples/s]
# Generating test split: 100%|█████| 1319/1319 [00:00<00:00, 288425.37 examples/s]
#   source: openai/gsm8k [train]
#   train: 2100 problems ready (preprocessed) | dropped 0 unparseable
#   source: openai/gsm8k [test]
#   test: 1319 problems ready (preprocessed) | dropped 0 unparseable
#
# Loading cached seeds + eval order from seeds_evalorder_pool2000_test.json
#
# Loading meta-llama/Llama-2-7b-chat-hf (fp16)...
# config.json: 100%|█████████████████████████████| 614/614 [00:00<00:00, 3.73MB/s]
# tokenizer_config.json: 1.62kB [00:00, 5.41MB/s]
# tokenizer.model: 100%|███████████████████████| 500k/500k [00:00<00:00, 1.21MB/s]
# tokenizer.json: 1.84MB [00:00, 18.7MB/s]
# special_tokens_map.json: 100%|█████████████████| 414/414 [00:00<00:00, 2.13MB/s]
# model.safetensors.index.json: 26.8kB [00:00, 53.5MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100%|████| 13.5G/13.5G [00:43<00:00, 290MB/s]
# Fetching 2 files: 100%|███████████████████████████| 2/2 [00:45<00:00, 22.94s/it]
# Download complete: 100%|████████████████████| 13.5G/13.5G [00:45<00:00, 293MB/s]
# Loading weights: 100%|████████████████████████| 291/291 [00:08<00:00, 35.44it/s]
# generation_config.json: 100%|███████████████████| 188/188 [00:00<00:00, 935kB/s]
#   loaded in 58s on cuda:0 | cuda=True
#   CHAT_MODE=True (chat template applied)
#   outputs -> /kaggle/working/fade/store_typed
#
# ######################################################################
# modules.json: 100%|████████████████████████████| 349/349 [00:00<00:00, 2.10MB/s]
# config_sentence_transformers.json: 100%|████████| 116/116 [00:00<00:00, 698kB/s]
# README.md: 10.5kB [00:00, 24.7MB/s]
# sentence_bert_config.json: 100%|██████████████| 53.0/53.0 [00:00<00:00, 259kB/s]
# config.json: 100%|█████████████████████████████| 612/612 [00:00<00:00, 3.33MB/s]
# model.safetensors: 100%|████████████████████| 90.9M/90.9M [00:00<00:00, 112MB/s]
# Loading weights: 100%|██████████████████████| 103/103 [00:00<00:00, 2489.52it/s]
# tokenizer_config.json: 100%|███████████████████| 350/350 [00:00<00:00, 1.87MB/s]
# vocab.txt: 232kB [00:00, 10.7MB/s]
# tokenizer.json: 466kB [00:00, 35.5MB/s]
# special_tokens_map.json: 100%|██████████████████| 112/112 [00:00<00:00, 768kB/s]
# config.json: 100%|█████████████████████████████| 190/190 [00:00<00:00, 1.23MB/s]
# #  FULL RUN | strategy 2=few_shot | n=1319 | backend=minilm | retrieval=3stage
# ######################################################################
#   pass1 10/1319 | pool=0 medium=2 bad=8 correct=0
#   pass1 20/1319 | pool=1 medium=3 bad=16 correct=3
#   pass1 30/1319 | pool=3 medium=5 bad=22 correct=8
#   pass1 40/1319 | pool=3 medium=7 bad=30 correct=10
#
# ==================================================================================
#   BATCH 1-50 of 1319   |   running accuracy 12/50 = 24.0%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#       1 monetary   .   BAD_WRONG      UNCLASSIFIED     2.0      18 0.00 1.00 sound work, wrong ans
#       2 counting   .   BAD_WRONG      UNCLASSIFIED     1.5       3 0.50 1.00 sound work, wrong ans
#       3 percentage .   BAD_WRONG      UNCLASSIFIED   150.0   70000 0.25 0.00 no #### emitted
#       4 time       .   BAD_WRONG      SM             180.0     540 0.00 1.00 sound work, wrong ans
#       5 monetary   .   BAD_WRONG      CE             300.0      20 0.50 0.00 ** answer in trace, LOST
#       6 percentage .   BAD_WRONG      UNCLASSIFIED    3.12      64 0.20 0.00 reasoning error
#       7 counting   .   MEDIUM_WRONG   UNCLASSIFIED   268.0     260 1.00 1.00 ** answer in trace, LOST
#       8 percentage .   MEDIUM_WRONG   UNCLASSIFIED    80.0     160 0.75 1.00 sound work, wrong ans
#       9 monetary   .   BAD_WRONG      UNCLASSIFIED   340.0      45 0.29 0.67 reasoning error
#      10 monetary   .   BAD_WRONG      UNCLASSIFIED   892.0     460 0.40 1.00 sound work, wrong ans
#      11 percentage Y   BAD_CORRECT    UNCLASSIFIED   366.0     366 0.60 1.00 correct
#      12 monetary   Y   GOOD           -              694.0     694 1.00 1.00 correct
#      13 monetary   .   BAD_WRONG      UNCLASSIFIED     7.5      13 0.50 1.00 no #### emitted
#      14 counting   .   BAD_WRONG      SM               3.0      18 0.00 0.50 reasoning error
#      15 percentage .   BAD_WRONG      CE              55.0      60 0.75 0.00 reasoning error
#      16 percentage .   BAD_WRONG      CE             250.0     125 1.00 0.00 ** answer in trace, LOST
#      17 time       Y   BAD_CORRECT    UNCLASSIFIED   230.0     230 0.25 1.00 correct
#      18 monetary   .   BAD_WRONG      UNCLASSIFIED  5750.0   57500 0.00 0.33 reasoning error
#      19 time       .   MEDIUM_WRONG   UNCLASSIFIED    84.0       7 0.67 1.00 sound work, wrong ans
#      20 time       .   BAD_WRONG      UNCLASSIFIED     4.0       6 0.25 1.00 sound work, wrong ans
#      21 arithmetic .   BAD_WRONG      UNCLASSIFIED     6.4      15 0.25 0.60 ** answer in trace, LOST
#      22 time       Y   GOOD           -               14.0      14 1.00 1.00 correct
#      23 time       Y   GOOD           -                7.0       7 1.00 1.00 correct
#      24 monetary   Y   BAD_CORRECT    CE               8.0       8 1.00 0.00 correct
#      25 percentage .   MEDIUM_WRONG   SM              78.0      26 0.00 1.00 sound work, wrong ans
#      26 monetary   Y   BAD_CORRECT    UNCLASSIFIED     2.0       2 1.00 1.00 correct
#      27 monetary   .   BAD_WRONG      UNCLASSIFIED    90.0     243 0.00 0.00 reasoning error
#      28 monetary   Y   BAD_CORRECT    CE              16.0      16 1.00 0.00 correct
#      29 time       .   MEDIUM_WRONG   UNCLASSIFIED    45.0      25 0.50 1.00 ** answer in trace, LOST
#      30 monetary   .   BAD_WRONG      CE              12.0     104 1.00 0.00 reasoning error
#      31 time       .   BAD_WRONG      UNCLASSIFIED   433.0     109 0.00 0.00 reasoning error
#      32 percentage Y   BAD_CORRECT    CE              80.0      80 1.00 0.00 correct
#      33 monetary   .   BAD_WRONG      UNCLASSIFIED     3.0      35 1.00 1.00 ** answer in trace, LOST
#      34 counting   .   BAD_WRONG      UNCLASSIFIED   110.0      70 0.00 0.00 reasoning error
#      35 counting   .   MEDIUM_WRONG   UNCLASSIFIED    22.0      23 0.50 1.00 sound work, wrong ans
#      36 percentage .   MEDIUM_WRONG   UNCLASSIFIED     5.0       9 0.67 1.00 sound work, wrong ans
#      37 monetary   .   BAD_WRONG      SM               5.0      75 0.00 1.00 sound work, wrong ans
#      38 monetary   Y   BAD_CORRECT    CE               2.0       2 0.50 0.50 correct
#      39 time       .   BAD_WRONG      CE              6.67      10 0.60 0.50 reasoning error
#      40 monetary   .   BAD_WRONG      UNCLASSIFIED    48.0      18 0.67 1.00 sound work, wrong ans
#      41 time       .   BAD_WRONG      CE               5.0       8 0.50 0.00 reasoning error
#      42 monetary   .   BAD_WRONG      CE              20.0     200 1.00 0.00 ** answer in trace, LOST
#      43 time       .   BAD_WRONG      SM               4.0      26 0.00 1.00 sound work, wrong ans
#      44 time       .   BAD_WRONG      CE             320.0      48 0.50 0.33 reasoning error
#      45 monetary   Y   BAD_CORRECT    UNCLASSIFIED    20.0      20 1.00 1.00 correct
#      46 time       .   BAD_WRONG      SM             244.0     104 0.00 0.60 reasoning error
#      47 monetary   .   BAD_WRONG      UNCLASSIFIED    20.0     163 0.00 0.00 reasoning error
#      48 percentage .   BAD_WRONG      CE             820.0     800 0.50 0.50 ** answer in trace, LOST
#      49 monetary   .   BAD_WRONG      UNCLASSIFIED     6.0       8 0.00 0.00 reasoning error
#      50 rate       Y   BAD_CORRECT    CE              30.0      30 0.67 0.00 correct
#   --------------------------------------------------------------------------------
#   batch: 12/50 correct | extraction-lost: 8 | rounding: 0 | no-####: 4/50
#   batch means: E=0.50 V=0.57 G=0.90 | labels {'BAD_WRONG': 31, 'MEDIUM_WRONG': 7, 'BAD_CORRECT': 9, 'GOOD': 3}
#   pool=3 medium=7 bad=40  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 8/50 (16%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 60/1319 | pool=3 medium=8 bad=49 correct=16
#   pass1 70/1319 | pool=4 medium=8 bad=58 correct=19
#   pass1 80/1319 | pool=6 medium=8 bad=66 correct=21
#   pass1 90/1319 | pool=7 medium=9 bad=74 correct=23
#
# ==================================================================================
#   BATCH 51-100 of 1319   |   running accuracy 24/100 = 24.0%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#      51 monetary   .   BAD_WRONG      UNCLASSIFIED    42.0     294 0.00 1.00 sound work, wrong ans
#      52 time       .   BAD_WRONG      UNCLASSIFIED    50.0       5 0.33 0.00 ** answer in trace, LOST
#      53 rate       Y   BAD_CORRECT    UNCLASSIFIED    15.0      15 0.33 1.00 correct
#      54 monetary   Y   BAD_CORRECT    UNCLASSIFIED    40.0      40 1.00 1.00 correct
#      55 time       .   MEDIUM_WRONG   UNCLASSIFIED    33.0      40 0.67 1.00 sound work, wrong ans
#      56 counting   Y   BAD_CORRECT    UNCLASSIFIED    14.0      14 1.00 1.00 correct
#      57 monetary   .   BAD_WRONG      SM               6.0       3 0.00 1.00 sound work, wrong ans
#      58 rate       .   BAD_WRONG      NR            1250.0      83 0.00 0.00 reasoning error
#      59 percentage .   BAD_WRONG      SM             512.0      57 0.00 1.00 sound work, wrong ans
#      60 rate       Y   BAD_CORRECT    CE             187.0     187 1.00 0.50 correct
#      61 percentage .   BAD_WRONG      UNCLASSIFIED    21.0      17 0.33 0.00 reasoning error
#      62 percentage Y   BAD_CORRECT    UNCLASSIFIED  1430.0    1430 1.00 1.00 correct
#      63 percentage .   BAD_WRONG      CE            5500.0   25000 0.50 0.33 reasoning error
#      64 percentage .   BAD_WRONG      UNCLASSIFIED   864.0    1596 0.33 0.50 reasoning error
#      65 counting   .   BAD_WRONG      UNCLASSIFIED     8.0     300 0.00 0.00 reasoning error
#      66 monetary   Y   BAD_CORRECT    UNCLASSIFIED    36.0      36 0.75 1.00 correct
#      67 time       .   BAD_WRONG      NR              20.0      48 0.00 0.00 no #### emitted
#      68 time       .   BAD_WRONG      UNCLASSIFIED   575.0     595 0.00 0.00 reasoning error
#      69 rate       .   BAD_WRONG      NR              15.0      36 0.00 0.00 reasoning error
#      70 monetary   Y   GOOD           -               60.0      60 1.00 1.00 correct
#      71 monetary   .   BAD_WRONG      UNCLASSIFIED 15770.0    7425 0.00 1.00 sound work, wrong ans
#      72 time       Y   GOOD           -               60.0      60 1.00 1.00 correct
#      73 monetary   Y   GOOD           -              221.0     221 1.00 1.00 correct
#      74 percentage .   BAD_WRONG      UNCLASSIFIED   765.0     255 0.50 1.00 sound work, wrong ans
#      75 monetary   .   BAD_WRONG      NR              67.6      88 0.00 0.00 reasoning error
#      76 monetary   .   BAD_WRONG      UNCLASSIFIED    10.0      60 0.00 0.00 reasoning error
#      77 monetary   .   BAD_WRONG      UNCLASSIFIED     8.0       5 0.20 0.33 reasoning error
#      78 time       .   BAD_WRONG      UNCLASSIFIED   320.0     100 0.00 0.00 reasoning error
#      79 monetary   .   BAD_WRONG      UNCLASSIFIED    10.0       6 0.00 0.67 reasoning error
#      80 percentage .   BAD_WRONG      CE             104.0      70 0.50 0.00 reasoning error
#      81 rate       .   BAD_WRONG      UNCLASSIFIED     1.0      10 0.00 1.00 sound work, wrong ans
#      82 time       Y   MEDIUM_CORRECT UNCLASSIFIED    17.0      17 0.50 1.00 correct
#      83 counting   .   BAD_WRONG      UNCLASSIFIED   300.0     623 0.00 1.00 sound work, wrong ans
#      84 rate       .   BAD_WRONG      CE              75.0     600 0.50 0.00 reasoning error
#      85 time       .   BAD_WRONG      UNCLASSIFIED    14.0      15 0.33 1.00 sound work, wrong ans
#      86 time       .   BAD_WRONG      SM              84.0      44 0.00 1.00 sound work, wrong ans
#      87 time       Y   GOOD           -               22.0      22 1.00 1.00 correct
#      88 percentage .   BAD_WRONG      UNCLASSIFIED  2655.0    9360 0.00 0.75 no #### emitted
#      89 counting   .   BAD_WRONG      NR            6800.0    8000 0.00 0.00 reasoning error
#      90 monetary   .   BAD_WRONG      CE              18.0      24 0.50 0.00 reasoning error
#      91 monetary   .   BAD_WRONG      UNCLASSIFIED   205.0     225 0.50 1.00 sound work, wrong ans
#      92 counting   .   BAD_WRONG      UNCLASSIFIED    12.0      28 0.00 0.00 reasoning error
#      93 time       .   BAD_WRONG      UNCLASSIFIED    14.0       4 0.00 0.00 reasoning error
#      94 percentage Y   BAD_CORRECT    CE              36.0      36 1.00 0.00 correct
#      95 counting   .   BAD_WRONG      UNCLASSIFIED   120.0     348 0.33 0.00 reasoning error
#      96 counting   .   BAD_WRONG      SM              34.0      40 0.00 1.00 sound work, wrong ans
#      97 time       .   MEDIUM_WRONG   CE              10.0       3 0.50 0.67 ** answer in trace, LOST
#      98 rate       .   BAD_WRONG      SM               8.0      12 0.00 1.00 sound work, wrong ans
#      99 time       .   BAD_WRONG      UNCLASSIFIED    30.0       5 0.00 0.50 ** answer in trace, LOST
#     100 monetary   .   BAD_WRONG      ST               0.0      58 0.50 1.00 sound work, wrong ans
#   --------------------------------------------------------------------------------
#   batch: 12/50 correct | extraction-lost: 3 | rounding: 0 | no-####: 4/50
#   batch means: E=0.34 V=0.56 G=0.90 | labels {'BAD_WRONG': 36, 'BAD_CORRECT': 7, 'MEDIUM_WRONG': 2, 'GOOD': 4, 'MEDIUM_CORRECT': 1}
#   pool=7 medium=10 bad=83  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 11/100 (11%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 110/1319 | pool=7 medium=12 bad=91 correct=24
#   pass1 120/1319 | pool=7 medium=13 bad=100 correct=25
#   pass1 130/1319 | pool=7 medium=16 bad=107 correct=25
#   pass1 140/1319 | pool=9 medium=18 bad=113 correct=28
#
# ==================================================================================
#   BATCH 101-150 of 1319   |   running accuracy 28/150 = 18.7%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#     101 time       .   BAD_WRONG      UNCLASSIFIED    71.0     175 0.17 0.33 no #### emitted
#     102 time       .   BAD_WRONG      UNCLASSIFIED    11.7       6 0.00 0.00 reasoning error
#     103 time       .   BAD_WRONG      SM             105.0      26 0.00 1.00 sound work, wrong ans
#     104 time       .   MEDIUM_WRONG   CE              14.0     140 0.50 0.00 reasoning error
#     105 counting   .   MEDIUM_WRONG   UNCLASSIFIED   725.0     500 0.75 1.00 sound work, wrong ans
#     106 time       .   BAD_WRONG      SM              14.0      20 0.00 1.00 sound work, wrong ans
#     107 rate       .   BAD_WRONG      CE             321.0      72 0.67 0.25 reasoning error
#     108 time       .   BAD_WRONG      UNCLASSIFIED    13.0       3 0.00 0.00 ** answer in trace, LOST
#     109 time       .   BAD_WRONG      UNCLASSIFIED     2.0      50 0.00 0.00 no #### emitted
#     110 monetary   .   BAD_WRONG      UNCLASSIFIED    10.0      28 0.33 1.00 sound work, wrong ans
#     111 time       .   BAD_WRONG      UNCLASSIFIED    18.0      45 0.00 0.40 reasoning error
#     112 monetary   .   BAD_WRONG      UNCLASSIFIED   880.0      16 0.25 1.00 ** answer in trace, LOST
#     113 time       .   BAD_WRONG      UNCLASSIFIED    25.0      24 1.00 1.00 ** answer in trace, LOST
#     114 time       .   BAD_WRONG      NR              10.0      25 0.00 0.00 reasoning error
#     115 time       .   BAD_WRONG      UNCLASSIFIED    60.0       6 0.00 0.00 ** answer in trace, LOST
#     116 percentage .   BAD_WRONG      UNCLASSIFIED   660.0      90 0.33 0.43 reasoning error
#     117 monetary   .   BAD_WRONG      UNCLASSIFIED   354.0      42 0.00 0.00 reasoning error
#     118 monetary   Y   MEDIUM_CORRECT UNCLASSIFIED   360.0     360 0.50 1.00 correct
#     119 time       .   BAD_WRONG      UNCLASSIFIED     2.0       4 0.67 1.00 sound work, wrong ans
#     120 percentage .   BAD_WRONG      NR           40000.0   95200 0.00 0.00 no #### emitted
#     121 time       .   BAD_WRONG      CE              60.0     240 0.50 0.00 reasoning error
#     122 time       .   BAD_WRONG      UNCLASSIFIED    29.0      27 0.33 1.00 sound work, wrong ans
#     123 time       .   BAD_WRONG      CE               3.0      48 0.40 0.00 reasoning error
#     124 time       .   MEDIUM_WRONG   UNCLASSIFIED    37.0      50 0.75 1.00 sound work, wrong ans
#     125 time       .   BAD_WRONG      NR               3.0      10 0.00 0.00 reasoning error
#     126 time       .   BAD_WRONG      SM              11.0      10 0.00 1.00 sound work, wrong ans
#     127 counting   .   MEDIUM_WRONG   UNCLASSIFIED    44.0      82 0.50 1.00 sound work, wrong ans
#     128 time       .   MEDIUM_WRONG   UNCLASSIFIED    70.0     120 0.50 1.00 sound work, wrong ans
#     129 monetary   .   BAD_WRONG      UNCLASSIFIED    20.0     880 1.00 1.00 ** answer in trace, LOST
#     130 monetary   .   BAD_WRONG      UNCLASSIFIED  1600.0   10000 0.50 1.00 no #### emitted
#     131 counting   Y   GOOD           -               30.0      30 1.00 1.00 correct
#     132 monetary   .   MEDIUM_WRONG   UNCLASSIFIED   440.0     940 0.50 1.00 sound work, wrong ans
#     133 monetary   .   BAD_WRONG      UNCLASSIFIED    40.0      60 0.50 1.00 sound work, wrong ans
#     134 time       .   BAD_WRONG      UNCLASSIFIED    37.0      13 0.33 1.00 sound work, wrong ans
#     135 monetary   Y   BAD_CORRECT    CE             720.0     720 1.00 0.00 correct
#     136 time       .   MEDIUM_WRONG   UNCLASSIFIED    20.0      40 1.00 1.00 sound work, wrong ans
#     137 counting   Y   GOOD           -                6.0       6 0.00 1.00 correct
#     138 percentage .   BAD_WRONG      UNCLASSIFIED    19.4      29 0.80 1.00 sound work, wrong ans
#     139 time       .   BAD_WRONG      CE              30.0     105 0.80 0.00 reasoning error
#     140 counting   .   BAD_WRONG      UNCLASSIFIED    36.0      70 0.00 0.00 reasoning error
#     141 percentage .   MEDIUM_WRONG   CE              25.0      20 0.50 0.50 ** answer in trace, LOST
#     142 counting   .   BAD_WRONG      UNCLASSIFIED   233.0     400 0.00 0.00 reasoning error
#     143 monetary   .   BAD_WRONG      NR              20.0     140 0.00 0.00 reasoning error
#     144 percentage .   BAD_WRONG      UNCLASSIFIED    10.0      16 0.25 0.83 sound work, wrong ans
#     145 monetary   .   BAD_WRONG      SM             186.0      20 0.00 1.00 sound work, wrong ans
#     146 time       .   BAD_WRONG      UNCLASSIFIED   400.0    4000 0.33 1.00 sound work, wrong ans
#     147 counting   .   MEDIUM_WRONG   CE             345.0    2125 0.67 0.50 reasoning error
#     148 time       .   BAD_WRONG      NR              45.0      75 0.25 0.00 reasoning error
#     149 monetary   .   MEDIUM_WRONG   UNCLASSIFIED    14.0      30 0.50 1.00 sound work, wrong ans
#     150 time       .   BAD_WRONG      CE              64.0      16 1.00 0.00 ** answer in trace, LOST
#   --------------------------------------------------------------------------------
#   batch: 4/50 correct | extraction-lost: 7 | rounding: 0 | no-####: 5/50
#   batch means: E=0.38 V=0.56 G=0.89 | labels {'BAD_WRONG': 36, 'MEDIUM_WRONG': 10, 'MEDIUM_CORRECT': 1, 'GOOD': 2, 'BAD_CORRECT': 1}
#   pool=9 medium=21 bad=120  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 18/150 (12%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 160/1319 | pool=10 medium=22 bad=128 correct=31
#   pass1 170/1319 | pool=11 medium=23 bad=136 correct=33
#   pass1 180/1319 | pool=11 medium=25 bad=144 correct=34
#   pass1 190/1319 | pool=11 medium=25 bad=154 correct=34
#
# ==================================================================================
#   BATCH 151-200 of 1319   |   running accuracy 35/200 = 17.5%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#     151 monetary   .   BAD_WRONG      UNCLASSIFIED    11.0       4 0.00 0.33 reasoning error
#     152 monetary   Y   MEDIUM_CORRECT UNCLASSIFIED     5.0       5 0.75 1.00 correct
#     153 monetary   Y   BAD_CORRECT    UNCLASSIFIED     4.0       4 0.67 1.00 correct
#     154 time       .   BAD_WRONG      SM              13.0      48 0.20 1.00 sound work, wrong ans
#     155 monetary   .   BAD_WRONG      UNCLASSIFIED   112.0     272 0.29 1.00 sound work, wrong ans
#     156 monetary   .   BAD_WRONG      SM            1563.0     280 0.17 1.00 sound work, wrong ans
#     157 monetary   .   BAD_WRONG      SM            1220.0    1400 0.00 1.00 no #### emitted
#     158 time       .   BAD_WRONG      NR              20.0      80 0.17 0.00 reasoning error
#     159 monetary   Y   GOOD           -               34.0      34 1.00 1.00 correct
#     160 counting   .   BAD_WRONG      SM               3.0      15 0.00 1.00 sound work, wrong ans
#     161 monetary   .   MEDIUM_WRONG   CE              -2.0      16 1.00 0.67 reasoning error
#     162 time       .   BAD_WRONG      UNCLASSIFIED    30.0      32 0.43 1.00 sound work, wrong ans
#     163 percentage .   BAD_WRONG      NR              32.0      92 0.00 0.00 reasoning error
#     164 monetary   .   BAD_WRONG      UNCLASSIFIED    35.0      50 0.67 1.00 sound work, wrong ans
#     165 percentage Y   GOOD           -               15.0      15 1.00 1.00 correct
#     166 monetary   Y   BAD_CORRECT    CE              77.0      77 1.00 0.00 correct
#     167 counting   .   BAD_WRONG      CE               2.0       5 0.50 0.00 reasoning error
#     168 time       .   BAD_WRONG      NR               0.0      16 0.00 0.00 reasoning error
#     169 monetary   .   BAD_WRONG      NR              32.0      18 0.00 0.00 reasoning error
#     170 time       .   BAD_WRONG      UNCLASSIFIED    45.0     120 0.33 1.00 sound work, wrong ans
#     171 monetary   .   BAD_WRONG      UNCLASSIFIED   143.7     150 0.25 0.33 no #### emitted
#     172 rate       .   MEDIUM_WRONG   CE            1170.0    1210 0.75 0.00 no #### emitted
#     173 time       .   BAD_WRONG      SM              23.0      51 0.00 1.00 sound work, wrong ans
#     174 percentage .   BAD_WRONG      UNCLASSIFIED  4650.0   18000 0.25 0.00 no #### emitted
#     175 time       .   BAD_WRONG      SM              48.0      95 0.00 1.00 no #### emitted
#     176 monetary   .   BAD_WRONG      SM            1200.0      15 0.00 1.00 sound work, wrong ans
#     177 time       .   BAD_WRONG      NR              None     100 0.00 0.00 no #### emitted
#     178 monetary   .   BAD_WRONG      UNCLASSIFIED  2550.0     350 0.14 0.33 reasoning error
#     179 counting   .   BAD_WRONG      UNCLASSIFIED   126.0     122 0.25 1.00 sound work, wrong ans
#     180 monetary   Y   MEDIUM_CORRECT UNCLASSIFIED   130.0     130 0.50 1.00 correct
#     181 counting   .   BAD_WRONG      NR              40.0      20 0.00 0.00 reasoning error
#     182 time       .   BAD_WRONG      NR               1.0     160 0.00 0.00 no #### emitted
#     183 time       .   BAD_WRONG      UNCLASSIFIED    34.0      23 0.00 1.00 sound work, wrong ans
#     184 time       .   BAD_WRONG      UNCLASSIFIED   202.0       2 0.33 1.00 no #### emitted
#     185 percentage .   BAD_WRONG      UNCLASSIFIED    50.0      25 0.00 0.00 no #### emitted
#     186 counting   .   BAD_WRONG      SM              18.0      30 0.00 1.00 sound work, wrong ans
#     187 time       .   BAD_WRONG      CE             160.0       5 0.50 0.50 ** answer in trace, LOST
#     188 percentage .   BAD_WRONG      UNCLASSIFIED    84.0     106 0.33 0.67 reasoning error
#     189 monetary   .   BAD_WRONG      NR             199.0      50 0.00 0.00 reasoning error
#     190 monetary   .   BAD_WRONG      UNCLASSIFIED    23.9      34 0.33 0.75 reasoning error
#     191 time       .   BAD_WRONG      UNCLASSIFIED     0.1     360 0.00 1.00 sound work, wrong ans
#     192 time       .   BAD_WRONG      UNCLASSIFIED     0.5       5 0.50 1.00 ** answer in trace, LOST
#     193 percentage .   BAD_WRONG      UNCLASSIFIED     3.0      91 0.20 0.88 sound work, wrong ans
#     194 time       .   BAD_WRONG      UNCLASSIFIED    36.0      24 0.25 1.00 sound work, wrong ans
#     195 monetary   Y   GOOD           -               10.0      10 1.00 1.00 correct
#     196 monetary   .   BAD_WRONG      NR               8.0      12 0.00 0.00 reasoning error
#     197 rate       .   BAD_WRONG      UNCLASSIFIED    20.0     120 0.00 0.50 reasoning error
#     198 counting   .   BAD_WRONG      UNCLASSIFIED 14377.0    6277 0.00 0.00 reasoning error
#     199 time       .   BAD_WRONG      UNCLASSIFIED   168.0     320 0.40 1.00 no #### emitted
#     200 monetary   .   BAD_WRONG      UNCLASSIFIED   100.0    7500 0.20 1.00 sound work, wrong ans
#   --------------------------------------------------------------------------------
#   batch: 7/50 correct | extraction-lost: 2 | rounding: 0 | no-####: 11/50
#   batch means: E=0.29 V=0.62 G=0.89 | labels {'BAD_WRONG': 41, 'MEDIUM_CORRECT': 2, 'BAD_CORRECT': 2, 'GOOD': 3, 'MEDIUM_WRONG': 2}
#   pool=12 medium=25 bad=163  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 20/200 (10%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 210/1319 | pool=14 medium=26 bad=170 correct=38
#   pass1 220/1319 | pool=15 medium=26 bad=179 correct=39
#   pass1 230/1319 | pool=20 medium=27 bad=183 correct=44
#   pass1 240/1319 | pool=21 medium=28 bad=191 correct=45
#
# ==================================================================================
#   BATCH 201-250 of 1319   |   running accuracy 46/250 = 18.4%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#     201 time       Y   GOOD           -               55.0      55 1.00 1.00 correct
#     202 percentage .   BAD_WRONG      UNCLASSIFIED 104000.0  114200 0.25 0.50 reasoning error
#     203 time       Y   MEDIUM_CORRECT UNCLASSIFIED   100.0     100 0.50 1.00 correct
#     204 time       .   BAD_WRONG      UNCLASSIFIED    25.0      31 0.50 1.00 no #### emitted
#     205 rate       Y   GOOD           -               98.0      98 1.00 1.00 correct
#     206 rate       .   BAD_WRONG      UNCLASSIFIED     4.0      98 0.00 0.00 reasoning error
#     207 time       .   BAD_WRONG      CE             740.0     860 0.40 0.67 reasoning error
#     208 time       .   BAD_WRONG      UNCLASSIFIED  3600.0    2600 0.50 1.00 sound work, wrong ans
#     209 time       .   BAD_WRONG      UNCLASSIFIED    38.0      76 0.00 0.00 reasoning error
#     210 monetary   .   BAD_WRONG      CE              24.0     145 0.50 0.50 reasoning error
#     211 monetary   .   BAD_WRONG      CE               8.0      10 0.50 0.75 reasoning error
#     212 time       .   BAD_WRONG      CE              14.0       4 1.00 0.00 reasoning error
#     213 monetary   .   BAD_WRONG      UNCLASSIFIED     3.0       5 0.25 1.00 sound work, wrong ans
#     214 monetary   .   BAD_WRONG      UNCLASSIFIED   205.0     250 0.33 0.33 reasoning error
#     215 time       .   BAD_WRONG      UNCLASSIFIED    -3.0       8 0.00 0.00 reasoning error
#     216 monetary   Y   GOOD           -               44.0      44 1.00 1.00 correct
#     217 percentage .   BAD_WRONG      CE            2235.0     220 0.50 0.67 reasoning error
#     218 counting   .   BAD_WRONG      CE              11.0      15 0.50 0.00 reasoning error
#     219 time       .   BAD_WRONG      UNCLASSIFIED    95.0      45 0.14 1.00 sound work, wrong ans
#     220 time       .   BAD_WRONG      NR              83.0      54 0.00 0.00 reasoning error
#     221 monetary   Y   GOOD           -               70.0      70 1.00 1.00 correct
#     222 counting   Y   GOOD           -               90.0      90 1.00 1.00 correct
#     223 counting   Y   GOOD           -              140.0     140 1.00 1.00 correct
#     224 monetary   .   MEDIUM_WRONG   UNCLASSIFIED  6500.0   20000 0.50 1.00 sound work, wrong ans
#     225 monetary   Y   GOOD           -              180.0     180 1.00 1.00 correct
#     226 time       Y   GOOD           -                9.0       9 1.00 1.00 correct
#     227 percentage .   BAD_WRONG      CE              36.0      33 0.67 0.50 reasoning error
#     228 monetary   .   BAD_WRONG      UNCLASSIFIED     7.5       9 0.25 0.50 reasoning error
#     229 time       .   BAD_WRONG      CE              12.0       1 0.75 0.00 ** answer in trace, LOST
#     230 percentage .   BAD_WRONG      CE              64.0      21 0.50 0.00 reasoning error
#     231 percentage .   BAD_WRONG      CE           27500.0  276000 0.60 0.33 no #### emitted
#     232 time       .   BAD_WRONG      CE              30.0      50 0.50 0.00 reasoning error
#     233 counting   .   BAD_WRONG      NR              25.0      75 0.00 0.00 reasoning error
#     234 counting   .   BAD_WRONG      UNCLASSIFIED    32.0      12 0.75 1.00 ** answer in trace, LOST
#     235 time       .   BAD_WRONG      SM              42.0      21 0.00 1.00 sound work, wrong ans
#     236 rate       .   BAD_WRONG      UNCLASSIFIED     4.0      10 0.00 1.00 sound work, wrong ans
#     237 time       .   BAD_WRONG      CE              19.0      31 0.67 0.00 reasoning error
#     238 monetary   Y   GOOD           -               90.0      90 1.00 1.00 correct
#     239 time       .   MEDIUM_WRONG   CE              58.0      68 0.67 0.50 reasoning error
#     240 percentage .   BAD_WRONG      SM              79.0     280 0.00 0.50 reasoning error
#     241 time       .   BAD_WRONG      NR              25.0      21 0.00 0.00 reasoning error
#     242 rate       .   MEDIUM_WRONG   UNCLASSIFIED     3.0       6 0.50 1.00 sound work, wrong ans
#     243 monetary   .   BAD_WRONG      UNCLASSIFIED     5.7       3 0.40 1.00 ** answer in trace, LOST
#     244 time       .   BAD_WRONG      SM             390.0     250 0.00 1.00 sound work, wrong ans
#     245 counting   .   BAD_WRONG      UNCLASSIFIED    10.0      20 1.00 1.00 ** answer in trace, LOST
#     246 time       .   BAD_WRONG      UNCLASSIFIED    10.0       7 0.00 0.50 reasoning error
#     247 percentage .   BAD_WRONG      CE             120.0   27000 0.40 0.67 ** answer in trace, LOST
#     248 monetary   .   BAD_WRONG      UNCLASSIFIED     7.0      32 0.00 0.50 reasoning error
#     249 monetary   Y   BAD_CORRECT    CE             300.0     300 0.50 0.00 correct
#     250 time       .   BAD_WRONG      UNCLASSIFIED   260.0    5600 0.33 1.00 sound work, wrong ans
#   --------------------------------------------------------------------------------
#   batch: 11/50 correct | extraction-lost: 5 | rounding: 0 | no-####: 3/50
#   batch means: E=0.48 V=0.61 G=0.93 | labels {'GOOD': 9, 'BAD_WRONG': 36, 'MEDIUM_CORRECT': 1, 'MEDIUM_WRONG': 3, 'BAD_CORRECT': 1}
#   pool=21 medium=29 bad=200  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 25/250 (10%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 260/1319 | pool=22 medium=29 bad=209 correct=47
#   pass1 270/1319 | pool=23 medium=30 bad=217 correct=49
#   pass1 280/1319 | pool=25 medium=30 bad=225 correct=51
#   pass1 290/1319 | pool=27 medium=30 bad=233 correct=53
#
# ==================================================================================
#   BATCH 251-300 of 1319   |   running accuracy 55/300 = 18.3%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#     251 percentage .   BAD_WRONG      CE              74.0      17 0.50 0.00 reasoning error
#     252 counting   .   BAD_WRONG      SM             569.0      70 0.00 1.00 sound work, wrong ans
#     253 time       .   BAD_WRONG      SM              42.0      73 0.20 1.00 sound work, wrong ans
#     254 arithmetic .   BAD_WRONG      UNCLASSIFIED    15.0      18 0.00 0.00 reasoning error
#     255 percentage .   BAD_WRONG      UNCLASSIFIED    40.0      84 0.00 0.33 reasoning error
#     256 rate       .   BAD_WRONG      UNCLASSIFIED     7.0     192 0.00 0.50 reasoning error
#     257 monetary   .   BAD_WRONG      UNCLASSIFIED   403.0      45 0.17 1.00 sound work, wrong ans
#     258 percentage .   BAD_WRONG      NR           73900.0    5600 0.00 0.00 reasoning error
#     259 monetary   Y   GOOD           -                6.0       6 1.00 1.00 correct
#     260 time       .   BAD_WRONG      UNCLASSIFIED     2.0     168 0.20 0.33 reasoning error
#     261 time       .   BAD_WRONG      NR              72.0      11 0.00 0.00 reasoning error
#     262 monetary   .   BAD_WRONG      UNCLASSIFIED   60.13      62 0.00 0.50 reasoning error
#     263 rate       Y   GOOD           -              270.0     270 1.00 1.00 correct
#     264 counting   .   MEDIUM_WRONG   UNCLASSIFIED     7.0       8 0.50 1.00 sound work, wrong ans
#     265 monetary   .   BAD_WRONG      SM             550.0     400 0.00 1.00 sound work, wrong ans
#     266 percentage .   BAD_WRONG      NR             482.0    9500 0.00 0.00 reasoning error
#     267 percentage .   BAD_WRONG      UNCLASSIFIED  8800.0  118000 0.00 1.00 sound work, wrong ans
#     268 percentage .   BAD_WRONG      SM              85.0      91 0.00 0.50 no #### emitted
#     269 monetary   .   BAD_WRONG      UNCLASSIFIED    11.0    1375 0.33 1.00 sound work, wrong ans
#     270 counting   Y   BAD_CORRECT    CE               4.0       4 1.00 0.00 correct
#     271 time       .   BAD_WRONG      UNCLASSIFIED   750.0     762 0.33 0.67 rounding (<2%)
#     272 rate       .   BAD_WRONG      SM              12.0      20 0.00 1.00 sound work, wrong ans
#     273 monetary   Y   GOOD           -                5.0       5 1.00 1.00 correct
#     274 rate       .   BAD_WRONG      CE              90.0     315 0.40 0.50 reasoning error
#     275 monetary   Y   GOOD           -             3200.0    3200 1.00 1.00 correct
#     276 time       .   BAD_WRONG      SM              72.0     138 0.00 1.00 sound work, wrong ans
#     277 counting   .   BAD_WRONG      UNCLASSIFIED    20.0       9 0.00 0.33 reasoning error
#     278 time       .   BAD_WRONG      UNCLASSIFIED   220.0       4 0.75 1.00 sound work, wrong ans
#     279 time       .   BAD_WRONG      UNCLASSIFIED    65.0      40 0.50 1.00 sound work, wrong ans
#     280 time       .   BAD_WRONG      CE               9.0       6 1.00 0.00 ** answer in trace, LOST
#     281 monetary   Y   GOOD           -                7.0       7 1.00 1.00 correct
#     282 time       .   BAD_WRONG      UNCLASSIFIED  2830.0    2450 0.20 1.00 sound work, wrong ans
#     283 monetary   .   BAD_WRONG      UNCLASSIFIED   495.0     195 0.00 0.00 reasoning error
#     284 rate       .   BAD_WRONG      SM             100.0      68 0.00 1.00 sound work, wrong ans
#     285 time       .   BAD_WRONG      CE             446.0     360 0.38 0.83 ** answer in trace, LOST
#     286 time       .   BAD_WRONG      UNCLASSIFIED    27.0      21 0.00 1.00 sound work, wrong ans
#     287 monetary   .   BAD_WRONG      NR               0.8      90 0.00 0.00 reasoning error
#     288 counting   .   BAD_WRONG      UNCLASSIFIED    19.0       8 0.20 0.00 ** answer in trace, LOST
#     289 rate       Y   GOOD           -                3.0       3 1.00 1.00 correct
#     290 time       .   BAD_WRONG      UNCLASSIFIED    20.0      16 0.00 0.50 reasoning error
#     291 counting   .   BAD_WRONG      UNCLASSIFIED    54.0     390 0.00 0.00 reasoning error
#     292 time       Y   BAD_CORRECT    UNCLASSIFIED     2.0       2 1.00 1.00 correct
#     293 monetary   .   BAD_WRONG      SM              90.0      75 0.00 1.00 sound work, wrong ans
#     294 time       .   BAD_WRONG      CE              88.0      83 0.50 0.80 sound work, wrong ans
#     295 time       Y   GOOD           -                3.0       3 1.00 1.00 correct
#     296 time       .   BAD_WRONG      CE             220.0     370 0.50 0.67 reasoning error
#     297 time       .   BAD_WRONG      UNCLASSIFIED    10.0       3 0.25 1.00 sound work, wrong ans
#     298 time       .   MEDIUM_WRONG   CE             -55.0      55 1.00 0.50 ** answer in trace, LOST
#     299 monetary   .   BAD_WRONG      NR              50.0     500 0.25 0.00 reasoning error
#     300 monetary   .   BAD_WRONG      UNCLASSIFIED   360.0   31800 0.33 1.00 sound work, wrong ans
#   --------------------------------------------------------------------------------
#   batch: 9/50 correct | extraction-lost: 4 | rounding: 1 | no-####: 2/50
#   batch means: E=0.35 V=0.64 G=0.93 | labels {'BAD_WRONG': 39, 'GOOD': 7, 'MEDIUM_WRONG': 2, 'BAD_CORRECT': 2}
#   pool=28 medium=31 bad=241  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 29/300 (10%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 310/1319 | pool=28 medium=34 bad=248 correct=57
#   pass1 320/1319 | pool=28 medium=35 bad=257 correct=58
#   pass1 330/1319 | pool=29 medium=35 bad=266 correct=60
#   pass1 340/1319 | pool=32 medium=35 bad=273 correct=63
#
# ==================================================================================
#   BATCH 301-350 of 1319   |   running accuracy 66/350 = 18.9%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#     301 time       .   BAD_WRONG      UNCLASSIFIED    42.0      78 0.00 0.00 reasoning error
#     302 counting   .   MEDIUM_WRONG   SM              32.0       8 0.00 1.00 sound work, wrong ans
#     303 monetary   .   BAD_WRONG      CE              30.0      15 0.50 0.00 reasoning error
#     304 monetary   .   BAD_WRONG      UNCLASSIFIED   900.0    1300 0.25 1.00 sound work, wrong ans
#     305 monetary   .   BAD_WRONG      NR             800.0    3200 0.00 0.00 reasoning error
#     306 percentage Y   BAD_CORRECT    CE               4.0       4 0.50 0.50 correct
#     307 time       Y   BAD_CORRECT    UNCLASSIFIED    10.0      10 1.00 1.00 correct
#     308 time       .   BAD_WRONG      UNCLASSIFIED     4.0      16 0.33 1.00 sound work, wrong ans
#     309 percentage .   MEDIUM_WRONG   CE              4.02       6 1.00 0.67 reasoning error
#     310 time       .   MEDIUM_WRONG   UNCLASSIFIED   120.0       8 0.67 1.00 sound work, wrong ans
#     311 monetary   .   BAD_WRONG      CE             300.0    2050 0.50 0.80 sound work, wrong ans
#     312 time       .   BAD_WRONG      CE              29.0      91 0.50 0.67 reasoning error
#     313 time       Y   BAD_CORRECT    CE              32.0      32 0.50 0.00 correct
#     314 time       .   BAD_WRONG      UNCLASSIFIED 184000.0  120000 0.00 0.00 no #### emitted
#     315 time       .   BAD_WRONG      NR              35.0      30 0.00 0.00 reasoning error
#     316 time       .   BAD_WRONG      UNCLASSIFIED    25.0      14 0.40 1.00 sound work, wrong ans
#     317 rate       .   BAD_WRONG      UNCLASSIFIED     3.0     156 0.00 0.00 no #### emitted
#     318 monetary   .   BAD_WRONG      UNCLASSIFIED    10.0      12 0.33 0.00 reasoning error
#     319 counting   .   MEDIUM_WRONG   UNCLASSIFIED    94.0     123 0.67 1.00 sound work, wrong ans
#     320 counting   .   BAD_WRONG      CE              30.0      15 0.50 0.00 ** answer in trace, LOST
#     321 time       .   BAD_WRONG      UNCLASSIFIED    15.0       8 0.00 1.00 sound work, wrong ans
#     322 monetary   Y   GOOD           -                1.0       1 1.00 1.00 correct
#     323 time       .   BAD_WRONG      NR              46.0       9 0.00 0.00 reasoning error
#     324 monetary   .   BAD_WRONG      UNCLASSIFIED    48.0      75 0.00 1.00 sound work, wrong ans
#     325 counting   Y   BAD_CORRECT    CE              14.0      14 1.00 0.00 correct
#     326 monetary   .   BAD_WRONG      UNCLASSIFIED    16.0  224000 0.17 0.50 no #### emitted
#     327 time       .   BAD_WRONG      UNCLASSIFIED     5.0      14 0.00 1.00 sound work, wrong ans
#     328 time       .   BAD_WRONG      UNCLASSIFIED   103.0      31 0.25 1.00 sound work, wrong ans
#     329 percentage .   BAD_WRONG      UNCLASSIFIED    36.0       2 0.00 1.00 sound work, wrong ans
#     330 counting   .   BAD_WRONG      UNCLASSIFIED    15.0      14 0.00 0.00 reasoning error
#     331 monetary   .   BAD_WRONG      UNCLASSIFIED    19.5      31 0.33 1.00 sound work, wrong ans
#     332 percentage .   BAD_WRONG      SM           17780.0    8400 0.14 0.50 no #### emitted
#     333 percentage Y   GOOD           -               44.0      44 1.00 1.00 correct
#     334 monetary   .   BAD_WRONG      UNCLASSIFIED    55.0     100 0.00 0.00 reasoning error
#     335 rate       .   BAD_WRONG      UNCLASSIFIED     2.5       6 0.50 1.00 no #### emitted
#     336 arithmetic Y   GOOD           -              310.0     310 1.00 1.00 correct
#     337 percentage .   BAD_WRONG      UNCLASSIFIED   520.0      72 0.40 1.00 sound work, wrong ans
#     338 time       Y   GOOD           -                1.0       1 1.00 1.00 correct
#     339 rate       .   BAD_WRONG      UNCLASSIFIED   300.0      60 0.00 0.00 reasoning error
#     340 counting   .   BAD_WRONG      UNCLASSIFIED    60.0     160 0.40 1.00 sound work, wrong ans
#     341 time       .   BAD_WRONG      CE               1.0       4 0.50 0.00 ** answer in trace, LOST
#     342 time       .   BAD_WRONG      CE             187.0     260 0.50 0.50 reasoning error
#     343 time       Y   GOOD           -               87.0      87 1.00 1.00 correct
#     344 time       .   BAD_WRONG      UNCLASSIFIED    30.0  180000 0.00 0.00 reasoning error
#     345 monetary   .   BAD_WRONG      CE               9.0       2 0.67 0.00 ** answer in trace, LOST
#     346 counting   .   BAD_WRONG      CE             160.0     310 0.67 0.50 no #### emitted
#     347 time       Y   GOOD           -                9.0       9 1.00 1.00 correct
#     348 percentage .   BAD_WRONG      UNCLASSIFIED     2.0      36 0.33 1.00 sound work, wrong ans
#     349 percentage Y   BAD_CORRECT    CE              10.0      10 1.00 0.50 correct
#     350 monetary   .   MEDIUM_WRONG   UNCLASSIFIED   220.0    2640 0.67 1.00 sound work, wrong ans
#   --------------------------------------------------------------------------------
#   batch: 11/50 correct | extraction-lost: 3 | rounding: 0 | no-####: 6/50
#   batch means: E=0.42 V=0.58 G=0.89 | labels {'BAD_WRONG': 34, 'MEDIUM_WRONG': 5, 'BAD_CORRECT': 5, 'GOOD': 6}
#   pool=34 medium=36 bad=280  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 32/350 (9%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 360/1319 | pool=35 medium=39 bad=286 correct=67
#   pass1 370/1319 | pool=35 medium=40 bad=295 correct=68
#   pass1 380/1319 | pool=37 medium=44 bad=299 correct=71
#   pass1 390/1319 | pool=39 medium=45 bad=306 correct=74
#
# ==================================================================================
#   BATCH 351-400 of 1319   |   running accuracy 75/400 = 18.8%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#     351 time       .   MEDIUM_WRONG   CE               7.5       8 1.00 0.00 reasoning error
#     352 monetary   .   BAD_WRONG      UNCLASSIFIED   100.0      10 1.00 1.00 ** answer in trace, LOST
#     353 monetary   Y   GOOD           -               21.0      21 1.00 1.00 correct
#     354 percentage .   BAD_WRONG      CE               4.2      20 0.40 0.50 reasoning error
#     355 monetary   .   BAD_WRONG      UNCLASSIFIED   320.0      45 0.25 1.00 sound work, wrong ans
#     356 monetary   .   BAD_WRONG      UNCLASSIFIED    30.0      34 0.00 0.00 reasoning error
#     357 monetary   .   MEDIUM_WRONG   UNCLASSIFIED    11.0      21 0.75 1.00 sound work, wrong ans
#     358 monetary   .   BAD_WRONG      SM              18.0       2 0.00 1.00 no #### emitted
#     359 monetary   .   BAD_WRONG      UNCLASSIFIED    13.0      20 0.33 1.00 sound work, wrong ans
#     360 monetary   .   MEDIUM_WRONG   CE               5.0       4 0.75 0.50 ** answer in trace, LOST
#     361 time       .   BAD_WRONG      UNCLASSIFIED    40.0      25 0.00 0.00 reasoning error
#     362 time       .   BAD_WRONG      UNCLASSIFIED     6.0      20 0.00 0.00 reasoning error
# ...
#    1020 time       .   BAD_WRONG      SM             163.0      98 0.00 1.00 sound work, wrong ans
#    1021 time       Y   GOOD           -               22.0      22 1.00 1.00 correct
#    1022 percentage Y   GOOD           -               36.0      36 1.00 1.00 correct
#    1023 monetary   .   BAD_WRONG      UNCLASSIFIED    30.0      12 0.00 1.00 sound work, wrong ans
#    1024 time       .   BAD_WRONG      SM              69.0      77 0.00 1.00 no #### emitted
#    1025 monetary   .   BAD_WRONG      CE             280.0     300 0.75 0.75 reasoning error
#    1026 time       .   MEDIUM_WRONG   UNCLASSIFIED    94.0      30 0.50 1.00 ** answer in trace, LOST
#    1027 percentage .   BAD_WRONG      UNCLASSIFIED  5400.0   43200 0.50 1.00 sound work, wrong ans
#    1028 monetary   .   BAD_WRONG      UNCLASSIFIED    1.33      12 0.00 0.00 reasoning error
#    1029 percentage .   BAD_WRONG      CE            2000.0     200 1.00 0.50 ** answer in trace, LOST
#    1030 percentage .   BAD_WRONG      UNCLASSIFIED     8.0      34 1.00 1.00 ** answer in trace, LOST
#    1031 percentage .   BAD_WRONG      UNCLASSIFIED    0.92      24 0.00 0.00 reasoning error
#    1032 monetary   .   BAD_WRONG      UNCLASSIFIED    37.0       5 0.00 0.00 reasoning error
#    1033 time       .   BAD_WRONG      NR               3.0     450 0.00 0.00 reasoning error
#    1034 monetary   .   BAD_WRONG      SM              27.0       2 0.00 1.00 sound work, wrong ans
#    1035 monetary   Y   GOOD           -               66.0      66 1.00 1.00 correct
#    1036 monetary   .   BAD_WRONG      UNCLASSIFIED     4.8      35 0.00 0.00 reasoning error
#    1037 counting   .   BAD_WRONG      UNCLASSIFIED     5.0      10 0.00 1.00 sound work, wrong ans
#    1038 monetary   .   BAD_WRONG      UNCLASSIFIED    19.0      10 0.25 1.00 sound work, wrong ans
#    1039 monetary   .   BAD_WRONG      UNCLASSIFIED    10.0       4 0.17 0.33 ** answer in trace, LOST
#    1040 monetary   .   BAD_WRONG      SM              72.0     160 0.00 1.00 sound work, wrong ans
#    1041 time       .   BAD_WRONG      UNCLASSIFIED  1741.0     736 0.25 0.50 reasoning error
#    1042 monetary   .   MEDIUM_WRONG   CE            1624.0     101 1.00 0.50 ** answer in trace, LOST
#    1043 monetary   .   BAD_WRONG      SM               8.5       3 0.20 0.67 ** answer in trace, LOST
#    1044 time       .   BAD_WRONG      CE           13008.0  130000 1.00 0.00 reasoning error
#    1045 monetary   .   BAD_WRONG      UNCLASSIFIED    45.0       1 0.25 1.00 sound work, wrong ans
#    1046 monetary   .   BAD_WRONG      CE            1280.0     420 0.50 0.00 reasoning error
#    1047 time       .   BAD_WRONG      UNCLASSIFIED     5.0     189 0.33 0.75 reasoning error
#    1048 time       .   BAD_WRONG      UNCLASSIFIED     2.5      10 0.00 0.00 reasoning error
#    1049 percentage .   BAD_WRONG      CE           12600.0    7400 0.50 0.00 reasoning error
#    1050 percentage .   MEDIUM_WRONG   CE              10.0      20 0.67 0.67 reasoning error
#   --------------------------------------------------------------------------------
#   batch: 5/50 correct | extraction-lost: 9 | rounding: 1 | no-####: 4/50
#   batch means: E=0.36 V=0.56 G=0.91 | labels {'BAD_WRONG': 42, 'GOOD': 5, 'MEDIUM_WRONG': 3}
#   pool=111 medium=108 bad=831  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 115/1050 (11%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 1060/1319 | pool=111 medium=109 bad=840 correct=201
#   pass1 1070/1319 | pool=112 medium=110 bad=848 correct=203
#   pass1 1080/1319 | pool=113 medium=111 bad=856 correct=205
#   pass1 1090/1319 | pool=115 medium=112 bad=863 correct=208
#
# ==================================================================================
#   BATCH 1051-1100 of 1319   |   running accuracy 212/1100 = 19.3%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#    1051 time       .   BAD_WRONG      SM            1630.0     655 0.00 1.00 sound work, wrong ans
#    1052 time       Y   BAD_CORRECT    CE              15.0      15 1.00 0.00 correct
#    1053 time       .   BAD_WRONG      NR             150.0     110 0.20 0.00 reasoning error
#    1054 monetary   .   MEDIUM_WRONG   UNCLASSIFIED    45.0      55 0.67 1.00 sound work, wrong ans
#    1055 monetary   .   BAD_WRONG      CE              20.0    2400 0.67 0.00 reasoning error
#    1056 percentage .   BAD_WRONG      UNCLASSIFIED  2560.0    2304 0.00 1.00 sound work, wrong ans
#    1057 time       .   BAD_WRONG      UNCLASSIFIED    17.0     156 0.00 0.00 reasoning error
#    1058 time       .   BAD_WRONG      CE              25.0      24 0.67 0.50 no #### emitted
#    1059 time       Y   BAD_CORRECT    CE             250.0     250 1.00 0.50 correct
#    1060 monetary   .   BAD_WRONG      SM              12.0       2 0.00 1.00 sound work, wrong ans
#    1061 rate       .   BAD_WRONG      SM              25.0      31 0.00 1.00 no #### emitted
#    1062 time       .   BAD_WRONG      UNCLASSIFIED    70.0      58 0.33 0.00 reasoning error
#    1063 monetary   .   BAD_WRONG      CE            1332.0     482 0.40 0.50 reasoning error
#    1064 percentage Y   GOOD           -              320.0     320 1.00 1.00 correct
#    1065 monetary   .   BAD_WRONG      UNCLASSIFIED   270.0     247 0.00 1.00 no #### emitted
#    1066 logic      .   BAD_WRONG      SM              90.0      95 0.00 0.50 reasoning error
#    1067 percentage Y   BAD_CORRECT    CE              14.0      14 1.00 0.60 correct
#    1068 monetary   .   BAD_WRONG      UNCLASSIFIED   335.0     245 0.25 0.50 reasoning error
#    1069 counting   .   MEDIUM_WRONG   CE              36.0      24 0.75 0.50 reasoning error
#    1070 time       .   BAD_WRONG      UNCLASSIFIED    80.0     300 0.00 0.00 reasoning error
#    1071 monetary   .   MEDIUM_WRONG   UNCLASSIFIED     9.0      18 1.00 1.00 ** answer in trace, LOST
#    1072 monetary   .   BAD_WRONG      CE              41.0     251 0.40 0.80 sound work, wrong ans
#    1073 monetary   .   BAD_WRONG      UNCLASSIFIED    25.0      85 0.40 1.00 sound work, wrong ans
#    1074 monetary   .   BAD_WRONG      UNCLASSIFIED     9.0      21 0.00 0.50 reasoning error
#    1075 time       Y   BAD_CORRECT    CE             750.0     750 1.00 0.50 correct
#    1076 monetary   .   BAD_WRONG      SM               5.0      16 0.17 1.00 sound work, wrong ans
#    1077 monetary   Y   GOOD           -              162.0     162 1.00 1.00 correct
#    1078 time       .   BAD_WRONG      CE              91.0     145 0.43 0.75 no #### emitted
#    1079 time       .   BAD_WRONG      SM              20.0       8 0.00 1.00 sound work, wrong ans
#    1080 percentage .   BAD_WRONG      CE            133.33      10 0.50 0.00 reasoning error
#    1081 time       .   BAD_WRONG      NR             100.0   72000 0.00 0.00 reasoning error
#    1082 logic      .   BAD_WRONG      UNCLASSIFIED   167.0     195 0.00 0.00 reasoning error
#    1083 time       Y   GOOD           -                2.0       2 1.00 1.00 correct
#    1084 monetary   .   BAD_WRONG      UNCLASSIFIED    0.08       2 0.25 1.00 sound work, wrong ans
#    1085 monetary   .   MEDIUM_WRONG   SM              40.0      20 0.00 1.00 sound work, wrong ans
#    1086 time       .   BAD_WRONG      CE              13.0      26 0.50 0.00 reasoning error
#    1087 percentage .   BAD_WRONG      CE            6770.0  131250 0.38 0.17 reasoning error
#    1088 time       Y   GOOD           -               12.0      12 1.00 1.00 correct
#    1089 monetary   .   BAD_WRONG      UNCLASSIFIED    9.83      30 0.17 0.00 ** answer in trace, LOST
#    1090 monetary   Y   BAD_CORRECT    UNCLASSIFIED    32.0      32 0.33 1.00 correct
#    1091 monetary   .   BAD_WRONG      CE              75.0      72 0.50 0.00 ** answer in trace, LOST
#    1092 monetary   .   BAD_WRONG      UNCLASSIFIED   100.0    1000 0.00 1.00 sound work, wrong ans
#    1093 time       .   BAD_WRONG      UNCLASSIFIED   100.0    1080 0.00 1.00 sound work, wrong ans
#    1094 monetary   Y   BAD_CORRECT    CE             144.0     144 0.86 0.75 correct
#    1095 percentage Y   BAD_CORRECT    UNCLASSIFIED    25.0      25 0.83 0.50 correct
#    1096 time       .   BAD_WRONG      UNCLASSIFIED    90.0     270 0.67 1.00 sound work, wrong ans
#    1097 percentage .   BAD_WRONG      UNCLASSIFIED    66.0     240 0.25 1.00 sound work, wrong ans
#    1098 time       Y   GOOD           -              480.0     480 1.00 1.00 correct
#    1099 time       Y   BAD_CORRECT    UNCLASSIFIED    30.0      30 1.00 1.00 correct
#    1100 monetary   .   BAD_WRONG      UNCLASSIFIED  6000.0       2 0.33 1.00 sound work, wrong ans
#   --------------------------------------------------------------------------------
#   batch: 13/50 correct | extraction-lost: 3 | rounding: 0 | no-####: 7/50
#   batch means: E=0.44 V=0.63 G=0.90 | labels {'BAD_WRONG': 33, 'BAD_CORRECT': 8, 'MEDIUM_WRONG': 4, 'GOOD': 5}
#   pool=116 medium=112 bad=872  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 118/1100 (11%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 1110/1319 | pool=116 medium=112 bad=882 correct=213
#   pass1 1120/1319 | pool=116 medium=116 bad=888 correct=215
#   pass1 1130/1319 | pool=117 medium=117 bad=896 correct=216
#   pass1 1140/1319 | pool=118 medium=117 bad=905 correct=217
#
# ==================================================================================
#   BATCH 1101-1150 of 1319   |   running accuracy 218/1150 = 19.0%
# ==================================================================================
#       # category   ok  label          diag            pred    gold    E    V note
#    1101 time       .   BAD_WRONG      UNCLASSIFIED    30.0       5 0.33 0.00 reasoning error
#    1102 time       .   BAD_WRONG      UNCLASSIFIED    20.0      16 0.25 1.00 sound work, wrong ans
#    1103 percentage .   BAD_WRONG      CE              64.0     113 0.57 0.75 reasoning error
#    1104 counting   .   BAD_WRONG      NR               5.0      90 0.00 0.00 reasoning error
#    1105 logic      .   BAD_WRONG      SM              18.0      24 0.00 1.00 sound work, wrong ans
#    1106 percentage .   BAD_WRONG      CE              50.0      40 0.50 0.00 ** answer in trace, LOST
#    1107 monetary   .   BAD_WRONG      CE               5.5       5 1.00 0.00 ** answer in trace, LOST
#    1108 percentage .   BAD_WRONG      UNCLASSIFIED   920.0     360 0.00 0.00 reasoning error
#    1109 monetary   Y   BAD_CORRECT    UNCLASSIFIED    38.0      38 1.00 1.00 correct
#    1110 arithmetic .   BAD_WRONG      CE              10.0       3 0.60 0.00 ** answer in trace, LOST
#    1111 time       .   BAD_WRONG      UNCLASSIFIED  4650.0      60 0.00 1.00 sound work, wrong ans
#    1112 monetary   .   MEDIUM_WRONG   UNCLASSIFIED   590.0     157 1.00 0.86 ** answer in trace, LOST
#    1113 time       .   BAD_WRONG      UNCLASSIFIED    34.0       5 0.25 1.00 sound work, wrong ans
#    1114 time       .   MEDIUM_WRONG   UNCLASSIFIED     8.0      -3 1.00 1.00 sound work, wrong ans
#    1115 monetary   .   BAD_WRONG      SM               5.0       8 0.00 1.00 sound work, wrong ans
#    1116 monetary   .   BAD_WRONG      UNCLASSIFIED     2.0       5 0.00 0.00 reasoning error
#    1117 percentage Y   MEDIUM_CORRECT UNCLASSIFIED    60.0      60 0.50 1.00 correct
#    1118 time       .   BAD_WRONG      UNCLASSIFIED     1.0       9 0.00 0.00 no #### emitted
#    1119 counting   .   BAD_WRONG      UNCLASSIFIED     7.0       5 0.60 1.00 ** answer in trace, LOST
#    1120 time       Y   MEDIUM_CORRECT UNCLASSIFIED    18.0      18 0.67 1.00 correct
#    1121 time       .   MEDIUM_WRONG   UNCLASSIFIED   280.0     560 0.67 1.00 sound work, wrong ans
#    1122 time       .   BAD_WRONG      NR               7.0      35 0.00 0.00 reasoning error
#    1123 time       .   BAD_WRONG      UNCLASSIFIED   340.0      18 0.12 0.00 reasoning error
#    1124 counting   Y   GOOD           -              105.0     105 1.00 1.00 correct
#    1125 counting   .   BAD_WRONG      UNCLASSIFIED     0.0      64 0.00 1.00 sound work, wrong ans
#    1126 rate       .   BAD_WRONG      UNCLASSIFIED     3.0      90 0.33 1.00 sound work, wrong ans
#    1127 time       .   BAD_WRONG      UNCLASSIFIED   105.0      50 0.00 0.00 reasoning error
#    1128 time       .   BAD_WRONG      NR             168.0     750 0.00 0.00 reasoning error
#    1129 time       .   BAD_WRONG      NR              34.0       9 0.00 0.00 reasoning error
#    1130 time       .   BAD_WRONG      NR              12.0       8 0.00 0.00 reasoning error
#    1131 rate       .   BAD_WRONG      UNCLASSIFIED   200.0      25 0.75 1.00 ** answer in trace, LOST
#    1132 percentage .   BAD_WRONG      UNCLASSIFIED    15.3      96 0.25 1.00 sound work, wrong ans
#    1133 monetary   .   BAD_WRONG      UNCLASSIFIED  1666.0   45000 0.00 1.00 sound work, wrong ans
#    1134 time       .   BAD_WRONG      UNCLASSIFIED     2.5      50 0.00 1.00 no #### emitted
#    1135 monetary   .   BAD_WRONG      UNCLASSIFIED     4.0       7 0.67 1.00 sound work, wrong ans
#    1136 rate       Y   GOOD           -               32.0      32 1.00 1.00 correct
#    1137 counting   .   BAD_WRONG      SM              48.0      26 0.00 1.00 sound work, wrong ans
#    1138 time       .   BAD_WRONG      NR              48.0      68 0.25 0.00 reasoning error
#    1139 time       .   BAD_WRONG      UNCLASSIFIED   160.0     700 0.00 0.00 reasoning error
#    1140 percentage .   BAD_WRONG      UNCLASSIFIED     4.0       1 0.25 0.00 reasoning error
#    1141 counting   .   BAD_WRONG      UNCLASSIFIED    17.0      27 0.50 1.00 sound work, wrong ans
#    1142 time       .   BAD_WRONG      UNCLASSIFIED    22.5      20 0.33 1.00 sound work, wrong ans
#    1143 counting   .   BAD_WRONG      SM              30.0       9 0.00 1.00 sound work, wrong ans
#    1144 time       .   MEDIUM_WRONG   UNCLASSIFIED   330.0     300 1.00 1.00 ** answer in trace, LOST
#    1145 counting   .   BAD_WRONG      UNCLASSIFIED    24.0      34 0.00 0.00 reasoning error
#    1146 monetary   .   BAD_WRONG      UNCLASSIFIED 26690.0     291 0.00 1.00 no #### emitted
#    1147 percentage .   BAD_WRONG      SM              80.0      16 0.00 1.00 sound work, wrong ans
#    1148 time       .   MEDIUM_WRONG   CE              23.0      22 0.75 0.75 reasoning error
#    1149 time       Y   GOOD           -                9.0       9 1.00 1.00 correct
#    1150 monetary   .   BAD_WRONG      CE              90.0      93 0.50 0.00 reasoning error
#   --------------------------------------------------------------------------------
#   batch: 6/50 correct | extraction-lost: 7 | rounding: 0 | no-####: 5/50
#   batch means: E=0.35 V=0.61 G=0.85 | labels {'BAD_WRONG': 39, 'BAD_CORRECT': 1, 'MEDIUM_WRONG': 5, 'MEDIUM_CORRECT': 2, 'GOOD': 3}
#   pool=119 medium=119 bad=912  (pool = GOOD traces available as typed positives)
#   [!] EXTRACTION: 125/1150 (11%) had the gold value in-trace but scored wrong -- fixable accuracy being lost.
# ==================================================================================
#   pass1 1160/1319 | pool=121 medium=119 bad=920 correct=222

# %%
# 6. Results
import json; s=json.load(open(f'{REPO}/store_typed/run_summary.json'))
print('TYPED  pass1=%.1f%%  final=%.1f%%  recovered=%d  pool=%d'%(
      100*s['pass1_accuracy'],100*s['final_accuracy'],s['recovered_by_retry'],s['final_pool_size']))
for it in s['iterations']:
    print('  iter%d MEDIUM %d/%d  BAD %d/%d  gap %+.3f'%(it['iter'],
          it['MEDIUM']['newly_correct'],it['MEDIUM']['retried'],
          it['BAD']['newly_correct'],it['BAD']['retried'],it['retry_worthiness_gap']))
print(open(f'{REPO}/store_typed/report.md').read())

# %%
# 7. Export
import shutil; shutil.make_archive('/kaggle/working/store_typed','zip',f'{REPO}/store_typed')
print('wrote /kaggle/working/store_typed.zip — download for the combined comparison')

# %%
# 8. FST decision gate (after this arm finishes)
# !cd {REPO} && python fst_gate.py --file store_typed/results.jsonl

# %% [markdown]
# Independent run — identical whether alone or parallel, given the shared eval order. Collect `store_typed.zip`.
